# %%
# CÓDIGO PARA EL PRE-PROCESAMIENTO DE NESTAB
# 1: PRIMER ARCHIVO QUE SE USA PARA EL CÓDIGO

# %%
import pandas as pd
df = pd.read_stata("county_income_market_access_1890-1930_updated_april2021.dta")

# %%
df
# Out:
#         cfips  bi_mktaccess1890  bi_mktaccess1900  bi_mktaccess1910  \
# 0     20111.0      3.093735e+16      4.830484e+16      1.435340e+17
# 1     42077.0      1.586074e+17      2.483034e+17      9.577208e+17
# 2     13071.0      1.559131e+15      7.346830e+15      4.198568e+16
# 3     36123.0      3.344018e+16      3.918072e+16      1.032136e+17
# 4     37001.0      1.148728e+16      2.050237e+16      1.006339e+17
# ...       ...               ...               ...               ...
# 1920  29101.0      3.674737e+16      4.673898e+16      1.033054e+17
# 1921  22051.0      1.305730e+16      1.546949e+16      6.494821e+16
# 1922  39005.0      3.976304e+16      4.017366e+16      1.364040e+17
# 1923  20177.0      8.823766e+16      1.337919e+17      3.875559e+17
# 1924  22109.0      0.000000e+00      2.972019e+16      7.376823e+16
#
#       bi_mktaccess1920  bi_mktaccess1930  bi_fmktaccess1890  \
# 0         7.620031e+16      1.693390e+17       3.135079e+09
# 1         5.984396e+17      1.635577e+18       5.177923e+09
# 2         3.433717e+16      4.855232e+16       1.806623e+09
# 3         4.569124e+16      1.003444e+17       4.201695e+09
# 4         6.498625e+16      1.600707e+17       3.125873e+09
# ...                ...               ...                ...
# 1920      4.431738e+16      8.237057e+16       3.223051e+09
# 1921      4.093155e+16      1.378789e+17       2.529178e+09
# 1922      7.619858e+16      1.993368e+17       4.216061e+09
# 1923      2.036823e+17      5.815653e+17       3.277268e+09
# 1924      2.994594e+16      5.154064e+16       2.121035e+09
#
#       bi_fmktaccess1900  bi_fmktaccess1910  bi_fmktaccess1920  \
# 0          3.969170e+09       7.375974e+09       5.598520e+09
# 1          6.456358e+09       1.244597e+10       9.422681e+09
# 2          2.292837e+09       4.377788e+09       3.344509e+09
# 3          5.271765e+09       1.006587e+10       7.691177e+09
# 4          3.936496e+09       7.564625e+09       5.783255e+09
# ...                 ...                ...                ...
# 1920       4.081564e+09       7.583595e+09       5.758612e+09
# 1921       3.223082e+09       6.121852e+09       4.661935e+09
# 1922       5.340327e+09       1.018437e+10       7.901379e+09
# 1923       4.146677e+09       7.686542e+09       5.831018e+09
# 1924       2.715667e+09       5.155455e+09       3.927035e+09
#
#       bi_fmktaccess1930
# 0          8.634622e+09
# 1          1.494576e+10
# 2          5.150564e+09
# 3          1.216549e+10
# 4          8.951699e+09
# ...                 ...
# 1920       8.898297e+09
# 1921       7.152808e+09
# 1922       1.246568e+10
# 1923       9.004255e+09
# 1924       6.038924e+09
#
# [1925 rows x 11 columns]

# %%
#CONVERTIR LA BASE DE MKT CORTE TRANSVERSAL A PANEL

A = df[ ["cfips", "bi_mktaccess1890"]]
A["year"] = 1890
A.rename(columns = {"bi_mktaccess1890": "mkt"}, inplace =  True)

for i in range(1900, 1940, 10):
    B = df[ ["cfips", f"bi_mktaccess{i}"]]
    B["year"] = i
    B.rename(columns = {f"bi_mktaccess{i}": "mkt"}, inplace = True)
    A = A.append(B, ignore_index=True)

A.to_stata("mkt.dta")
# Out:
# <ipython-input-6-7527d03e94bf>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A["year"] = 1890
# C:\Users\War\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# <ipython-input-6-7527d03e94bf>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   B["year"] = i

# %%
#CONVERTIR LA BASE DE FMKT CORTE TRANSVERSAL A PANEL

A = df[ ["cfips", "bi_fmktaccess1890"]]
A["year"] = 1890
A.rename(columns = {"bi_fmktaccess1890": "fmkt"}, inplace =  True)

for i in range(1900, 1940, 10):
    B = df[ ["cfips", f"bi_fmktaccess{i}"]]
    B["year"] = i
    B.rename(columns = {f"bi_fmktaccess{i}": "fmkt"}, inplace = True)
    A = A.append(B, ignore_index=True)

A.to_stata("fmkt.dta")
# Out:
# <ipython-input-7-00a65698e907>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   A["year"] = 1890
# C:\Users\War\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# <ipython-input-7-00a65698e907>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   B["year"] = i
